# %% [markdown]
# # 3D medical image segmentation EF

# %% [markdown]
# This notebook shows how to use SAM 2 for interactive segmentation in 3D images. It will cover the following:
#
# - propagating a mask to get _masklets_ throughout the video

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# use bfloat16 for the entire notebook
torch.autocast(device_type="cuda", dtype=torch.bfloat16).__enter__()

if torch.cuda.get_device_properties(0).major >= 8:
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True

# %% [markdown]
# ### Loading the SAM 2 video predictor

# %%
from sam2.build_sam import build_sam2_video_predictor

sam2_checkpoint = "../checkpoints/sam21_finetuned_large.pth"
model_cfg = "configs/sam2.1/sam2.1_hiera_l.yaml"
#sam2_checkpoint = "../checkpoints/sam2_hiera_large.pt"
#model_cfg = "sam2_hiera_l.yaml"

predictor = build_sam2_video_predictor(model_cfg, sam2_checkpoint)

# %%
# def show_mask(mask, ax, obj_id=None, random_color=False):
#     if random_color:
#         color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
#     else:
#         cmap = plt.get_cmap("tab10")
#         cmap_idx = 0 if obj_id is None else obj_id
#         color = np.array([*cmap(cmap_idx)[:3], 0.6])
#     h, w = mask.shape[-2:]
#     mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
#     ax.imshow(mask_image)

# Color masks Red Green and Blue
def show_mask(mask, ax, random_color=False):
    # Define colors for each class (RGBA for transparency)
    colors = {
        0: np.array([0.0, 0.0, 0.0, 0.0]),  # Transparent background
        1: np.array([1.0, 0.0, 0.0, 0.6]),  # Red for class 1
        2: np.array([0.0, 1.0, 0.0, 0.6]),  # Green for class 2
        3: np.array([0.0, 0.0, 1.0, 0.6])   # Blue for class 3
    }

    # Random color option
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
        mask_image = mask.reshape(mask.shape[0], mask.shape[1], 1) * color.reshape(1, 1, -1)
    else:
        # Initialize an empty image with the same shape as the mask but with RGBA channels
        h, w = mask.shape[-2:]
        mask_image = np.zeros((h, w, 4))

        # Apply color based on class value
        for class_id, color in colors.items():
            mask_image += (mask == class_id).reshape(h, w, 1) * color.reshape(1, 1, -1)

    ax.imshow(mask_image)
    ax.axis("off")


def show_points(coords, labels, ax, marker_size=200):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)

# %% [markdown]
# #### Select an example video

# %% [markdown]
# We assume that the video is stored as a list of JPEG frames with filenames like `<frame_index>.jpg`.
#
# For your custom videos, you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# `video_dir` a directory of JPEG frames with filenames like `<frame_index>.jpg`
video_dir = "./videos/cardiac"

# scan all the JPEG frame names in this directory
frame_names = [
    p for p in os.listdir(video_dir)
    if os.path.splitext(p)[-1] in [".jpg", ".jpeg", ".JPG", ".JPEG"]
]
frame_names.sort(key=lambda p: int(os.path.splitext(p)[0]))
print("len of frames: ", len(frame_names))

# take a look the first video frame
frame_idx = len(frame_names) // 2
plt.figure(figsize=(6, 6))
plt.title(f"frame {frame_idx}")
plt.imshow(Image.open(os.path.join(video_dir, frame_names[frame_idx])), cmap='gray')
# Out:
# len of frames:  7

# %% [markdown]
# #### Initialize the inference state

# %% [markdown]
# load one mask

# %%
out_mask_logits = np.load(os.path.join(video_dir, frame_names[frame_idx].replace(".jpg", ".npy")))
plt.figure(figsize=(6, 6))
plt.title(f"frame {frame_idx} with mask")
plt.imshow(Image.open(os.path.join(video_dir, frame_names[frame_idx])), cmap ='gray')
show_mask(out_mask_logits, plt.gca())

# %% [markdown]
# SAM 2 requires stateful inference for interactive video segmentation, so we need to initialize an **inference state** on this video.
#
# During initialization, it loads all the JPEG frames in `video_path` and stores their pixels in `inference_state` (as shown in the progress bar below).
# #### Propagate the prompts to get the masklet across the video

# %%
# run propagation to get the mask for the entire video
inference_state = predictor.init_state(video_path=video_dir)
# Out:
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 47.97it/s]

# %%
ann_obj_id = 1

# Initialize dictionaries to store video segments for each class
class_1_segments = {}
class_2_segments = {}
class_3_segments = {}

for class_id in [1, 2, 3]:
    
    # Need to reset state for each class
    predictor.reset_state(inference_state)
    
    # Add new mask for the current class
    predictor.add_new_mask(inference_state=inference_state, frame_idx=frame_idx, obj_id=ann_obj_id, mask=out_mask_logits == class_id)
    
    # Initialize video_segments for this class
    video_segments = {}  # video_segments contains the per-frame segmentation results

    # Direct propagation   
    for out_frame_idx, out_obj_ids, class_mask in predictor.propagate_in_video(inference_state):
        # Store results for the current class in the appropriate variable
        for i, out_obj_id in enumerate(out_obj_ids):
            class_mask_np = (class_mask[i] > 0.0).cpu().numpy()
            if class_id == 1:
                class_1_segments[out_frame_idx] = {out_obj_id: class_mask_np}
            elif class_id == 2:
                class_2_segments[out_frame_idx] = {out_obj_id: class_mask_np}
            elif class_id == 3:
                class_3_segments[out_frame_idx] = {out_obj_id: class_mask_np}

    # Reverse propagation    
    for out_frame_idx, out_obj_ids, class_mask in predictor.propagate_in_video(inference_state, start_frame_idx=frame_idx-1, reverse=True):
        # Store results for the current class in the appropriate variable
        for i, out_obj_id in enumerate(out_obj_ids):
            class_mask_np = (class_mask[i] > 0.0).cpu().numpy()
            if class_id == 1:
                class_1_segments[out_frame_idx] = {out_obj_id: class_mask_np}
            elif class_id == 2:
                class_2_segments[out_frame_idx] = {out_obj_id: class_mask_np}
            elif class_id == 3:
                class_3_segments[out_frame_idx] = {out_obj_id: class_mask_np}
# Out:
# propagate in video:   0%|                                                                        | 0/4 [00:00<?, ?it/s]C:\Users\Windows\Desktop\Tijana\sam2-main\sam2-main\sam2\modeling\sam\transformer.py:344: UserWarning: Memory efficient kernel not used because: (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:778.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# C:\Users\Windows\Desktop\Tijana\sam2-main\sam2-main\sam2\modeling\sam\transformer.py:344: UserWarning: Memory Efficient attention has been runtime disabled. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen/native/transformers/sdp_utils_cpp.h:558.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# C:\Users\Windows\Desktop\Tijana\sam2-main\sam2-main\sam2\modeling\sam\transformer.py:344: UserWarning: Flash attention kernel not used because: (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:780.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# C:\Users\Windows\Desktop\Tijana\sam2-main\sam2-main\sam2\modeling\sam\transformer.py:344: UserWarning: Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:604.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# C:\Users\Windows\Desktop\Tijana\sam2-main\sam2-main\sam2\modeling\sam\transformer.py:344: UserWarning: CuDNN attention kernel not used because: (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:782.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# C:\Users\Windows\Desktop\Tijana\sam2-main\sam2-main\sam2\modeling\sam\transformer.py:344: UserWarning: head_dim should be no more than 128 (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:386.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# C:\Users\Windows\anaconda3\envs\medsam2\Lib\site-packages\torch\nn\modules\module.py:1747: UserWarning: Flash Attention kernel failed due to: No available kernel. Aborting execution.
# Falling back to all available kernels for scaled_dot_product_attention (which may have a slower speed).
#   return forward_call(*args, **kwargs)
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.36it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.92it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.81it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 12.71it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.86it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 12.12it/s]

# %%
# Initialize a global counter to track the color cycle
color_cycle = [np.array([1.0, 0.0, 0.0, 0.6]),  # Red
               np.array([0.0, 1.0, 0.0, 0.6]),  # Green
               np.array([0.0, 0.0, 1.0, 0.6])]  # Blue

color_index = 0  # Start with red

def show_mask_sam(mask, ax, random_color=False):
    global color_index  # Use the global color_index to track color

    # Get the current color from the cycle
    color = color_cycle[color_index]

    # Random color option (if needed)
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
        mask_image = mask.reshape(mask.shape[0], mask.shape[1], 1) * color.reshape(1, 1, -1)
    else:
        # Initialize an empty image with the same shape as the mask but with RGBA channels
        h, w = mask.shape[-2:]
        mask_image = np.zeros((h, w, 4))

        # Apply color based on the mask class
        mask_image += (mask == 1).reshape(h, w, 1) * color.reshape(1, 1, -1)

    # Show the mask
    ax.imshow(mask_image)
    ax.axis("off")

    # Update the color cycle (move to the next color)
    color_index = (color_index + 1) % len(color_cycle)

# %%
vis_frame_stride = 1
plt.close("all")
for out_frame_idx in range(0, len(frame_names), vis_frame_stride):
    fig, axes = plt.subplots(1, 3, figsize=(18, 8))  
    # subplot
    axes[0].set_title(f"frame {out_frame_idx} - Original")
    original_image = Image.open(os.path.join(video_dir, frame_names[out_frame_idx]))
    axes[0].imshow(original_image,cmap='gray')
    
    # Ground truth subplot
    axes[1].set_title(f"frame {out_frame_idx} - GT")
    gt_image = Image.open(os.path.join(video_dir, frame_names[out_frame_idx]))
    axes[1].imshow(gt_image,cmap='gray')
    out_mask_logits_gt = np.load(os.path.join(video_dir, frame_names[out_frame_idx].replace(".jpg", ".npy")))
    show_mask(out_mask_logits_gt, axes[1])
    
    # Predicted result subplot
    axes[2].set_title(f"frame {out_frame_idx} - Prediction")
    pred_image = Image.open(os.path.join(video_dir, frame_names[out_frame_idx]))
    axes[2].imshow(pred_image, cmap='gray')

    # Assuming axes[2] is the plot axis
    for out_obj_id, out_mask in class_1_segments[out_frame_idx].items():
        show_mask_sam(out_mask, axes[2])          
    for out_obj_id, out_mask in class_2_segments[out_frame_idx].items():
       show_mask_sam(out_mask, axes[2])  
    for out_obj_id, out_mask in class_3_segments[out_frame_idx].items():
       show_mask_sam(out_mask, axes[2])

    plt.show()

# %%
# Class LV
video_seg_3d_1 = np.stack([class_1_segments[k][1] for k in class_1_segments])
video_seg_3d_2 = np.stack([class_2_segments[k][1] for k in class_2_segments])
video_seg_3d_3 = np.stack([class_3_segments[k][1] for k in class_3_segments])
#gt_3d = np.stack([np.load(os.path.join(video_dir, frame_names[k].replace(".jpg", ".npy")))[None] for k in class_1_segments])

# Initialize empty lists to hold the 3D arrays for each class (0, 1, 2, 3)
gt_3d_class_0 = []
gt_3d_class_1 = []
gt_3d_class_2 = []
gt_3d_class_3 = []

# Iterate through class_1_segments to load the .npy files and process them
for k in class_1_segments:
    # Load the .npy file corresponding to frame_names[k]
    frame_path = os.path.join(video_dir, frame_names[k].replace(".jpg", ".npy"))
    mask = np.load(frame_path)
    
    # Create separate binary masks for each class (0, 1, 2, 3)
    mask_class_0 = (mask == 0).astype(np.uint8)  # 1 for class 0, 0 otherwise
    mask_class_1 = (mask == 1).astype(np.uint8)  # 1 for class 1, 0 otherwise
    mask_class_2 = (mask == 2).astype(np.uint8)  # 1 for class 2, 0 otherwise
    mask_class_3 = (mask == 3).astype(np.uint8)  # 1 for class 3, 0 otherwise
    
    # Append each binary mask (with new axis) to the corresponding list
    gt_3d_class_0.append(mask_class_0[None])  # Shape will be (1, height, width)
    gt_3d_class_1.append(mask_class_1[None])
    gt_3d_class_2.append(mask_class_2[None])
    gt_3d_class_3.append(mask_class_3[None])

# Stack the lists into 3D arrays
gt_3d_class_0 = np.stack(gt_3d_class_0)  # Shape: (num_frames, 1, height, width)
gt_3d_class_1 = np.stack(gt_3d_class_1)
gt_3d_class_2 = np.stack(gt_3d_class_2)
gt_3d_class_3 = np.stack(gt_3d_class_3)

# %%
import torch
from monai.metrics import DiceHelper, compute_surface_dice

# Class RV
n_classes, batch_size = 1, 1
spatial_shape = (video_seg_3d_1.shape[0], video_seg_3d_1.shape[2], video_seg_3d_1.shape[3]) 

y_pred = torch.tensor(video_seg_3d_1).float().reshape(batch_size, n_classes, *spatial_shape)  # prediction
y = torch.tensor(gt_3d_class_1).float().reshape(batch_size, n_classes, *spatial_shape)  # ground truth

score, not_nans = DiceHelper(include_background=False, sigmoid=True, softmax=True)(y_pred, y)
print('RV dice score:', score)

# Class MYO
spatial_shape = (video_seg_3d_2.shape[0], video_seg_3d_2.shape[2], video_seg_3d_2.shape[3]) 

y_pred = torch.tensor(video_seg_3d_2).float().reshape(batch_size, n_classes, *spatial_shape)  # prediction
y = torch.tensor(gt_3d_class_2).float().reshape(batch_size, n_classes, *spatial_shape)  # ground truth

score, not_nans = DiceHelper(include_background=False, sigmoid=True, softmax=True)(y_pred, y)
print('MYO dice score:', score)

# Class LV
spatial_shape = (video_seg_3d_3.shape[0], video_seg_3d_3.shape[2], video_seg_3d_3.shape[3]) 

y_pred = torch.tensor(video_seg_3d_3).float().reshape(batch_size, n_classes, *spatial_shape)  # prediction
y = torch.tensor(gt_3d_class_3).float().reshape(batch_size, n_classes, *spatial_shape)  # ground truth

score, not_nans = DiceHelper(include_background=False, sigmoid=True, softmax=True)(y_pred, y)
print('LV dice score:', score)
# Out:
# RV dice score: tensor([0.8206])
# MYO dice score: tensor([0.9236])
# LV dice score: tensor([0.9005])

# %% [markdown]
# ## Calculate EF for one example (LV)

# %%
import pandas as pd

# Load the voxel spacing from the CSV file
voxel_spacing_df = pd.read_csv('patient_voxel_spacing.csv')
voxel_spacing_df.set_index('Patient', inplace=True)  # Set patient names as index for easy lookup

# example first row is the match
# Get voxel spacing for the current patient
patient_id = 'patient111'
# Clean and convert the voxel spacing string to a list of floats
voxel_spacing_str = voxel_spacing_df.loc[patient_id].values[0]
voxel_spacing = [float(x) for x in voxel_spacing_str.strip('()').split(',')]  # Convert to float list
voxel_spacing_tuple = tuple(voxel_spacing)  # Create a tuple for calculations
print(voxel_spacing_tuple)

vis_frame_stride = 1
ev = 0

# Process masks in class_3_segments
for out_frame_idx in range(0, len(frame_names), vis_frame_stride):
    for out_obj_id, out_mask in class_3_segments[out_frame_idx].items():
        # Convert True/False mask to 0/1
        binary_mask = out_mask.astype(int)
        # Count the number of voxels
        voxel_count = np.sum(binary_mask)
        
        # Calculate the scaled EV (in voxel units) - volume whatever it is ESV or EDV
        ev += voxel_count * np.prod(voxel_spacing_tuple)  # No explicit units
        
print(f"Object {out_obj_id}: EV = {ev:.2f}")
# Out:
# (1.40625, 1.40625, 10.0)
# Object 1: EV = 24778.56

# %% [markdown]
# ### Calculate for all patients

# %%
import csv
import pandas as pd

# Define paths to image and mask directories
video_dir = "./videos/Test/"
images_dir = os.path.join(video_dir, "image")
mask_dir = os.path.join(video_dir, "mask")

# Load the voxel spacing from the CSV file
voxel_spacing_df = pd.read_csv('patient_voxel_spacing.csv')
voxel_spacing_df.set_index('Patient', inplace=True)  # Set patient names as index for easy lookup

# Create a list to store all results for writing to CSV
results = []

# Iterate through each patient folder in the images directory
for patient_folder in os.listdir(images_dir):
    patient_images_path = os.path.join(images_dir, patient_folder)

    # Extract the part after the last underscore
    patient_id = patient_images_path.split('_')[-1]
    #print(patient_id)
    # Split by underscore and extract the frame part
    frame_part = patient_images_path.split('_')[-2]
    #print(frame_part)

    # Get all JPEG frame names in the patient's images folder
    frame_names = [
        p for p in os.listdir(patient_images_path)
        if os.path.splitext(p)[-1] in [".jpg", ".jpeg", ".JPG", ".JPEG"]
    ]
    frame_names.sort(key=lambda p: int(os.path.splitext(p)[0]))  # Sort by frame number
    frame_idx = len(frame_names) // 2

    out_mask_logits = np.load(os.path.join(mask_dir, patient_folder, frame_names[frame_idx].replace(".jpg", ".npy")))
    
    # Clean and convert the voxel spacing string to a list of floats
    voxel_spacing_str = voxel_spacing_df.loc[patient_id].values[0]
    voxel_spacing = [float(x) for x in voxel_spacing_str.strip('()').split(',')]  # Convert to float list
    voxel_spacing_tuple = tuple(voxel_spacing)  # Create a tuple for calculations

    # SAM propagation prediction -------------------------------------------------------------------------------------
    # run propagation to get the mask for the entire video
    inference_state = predictor.init_state(video_path=patient_images_path)
    
    ann_obj_id = 1
    
    # Initialize dictionaries to store video segments for LV
    class_3_segments = {}
    
    for class_id in [3]:
        
        # Need to reset state for each class
        predictor.reset_state(inference_state)
        
        # Add new mask for the current class
        predictor.add_new_mask(inference_state=inference_state, frame_idx=frame_idx, obj_id=ann_obj_id, mask=out_mask_logits == class_id)
    
        # Direct propagation   
        for out_frame_idx, out_obj_ids, class_mask in predictor.propagate_in_video(inference_state):
            # Store results for the current class in the appropriate variable
            for i, out_obj_id in enumerate(out_obj_ids):
                class_mask_np = (class_mask[i] > 0.0).cpu().numpy()
                if class_id == 3:
                    class_3_segments[out_frame_idx] = {out_obj_id: class_mask_np}
    
        # Reverse propagation    
        for out_frame_idx, out_obj_ids, class_mask in predictor.propagate_in_video(inference_state, start_frame_idx=frame_idx-1, reverse=True):
            # Store results for the current class in the appropriate variable
            for i, out_obj_id in enumerate(out_obj_ids):
                class_mask_np = (class_mask[i] > 0.0).cpu().numpy()
                if class_id == 3:
                    class_3_segments[out_frame_idx] = {out_obj_id: class_mask_np}
    # SAM propagation ends -------------------------------------------------------------------------------------
    
    vis_frame_stride = 1
    ev = 0
    
    # Process masks in class_3_segments
    for out_frame_idx in range(0, len(frame_names), vis_frame_stride):
        for out_obj_id, out_mask in class_3_segments[out_frame_idx].items():
            # Convert True/False mask to 0/1
            binary_mask = out_mask.astype(int)
            
            # Count the number of voxels
            voxel_count = np.sum(binary_mask)
            
            # Calculate the scaled EV (in voxel units) - volume whatever it is ESV or EDV
            ev += voxel_count * np.prod(voxel_spacing_tuple)  # No explicit units

    #print(patient_id)
    #print(f"Object {out_obj_id}: EV = {ev:.2f}")
        
    # Append the result to the list
    results.append([patient_id, frame_part, f"{ev:.2f}"])

# Write all results to CSV
csv_file_path = 'temp_patient_VOL_predicted.csv'
with open(csv_file_path, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Patient ID", "Frame Name", "EV"])
    writer.writerows(results)

print(f"Results written to {csv_file_path}")
# Out:
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.22it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.86it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 12.10it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 44.83it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.72it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 12.51it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 50.84it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.89it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.21it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 49.89it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.75it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.35it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 51.29it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.95it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.17it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 51.33it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.55it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.26it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 46.89it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.46it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.80it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.99it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.13it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 12.03it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 48.12it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.37it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.14it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 52.32it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.14it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.16it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 47.57it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 19.37it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 12.69it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 50.02it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.18it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.99it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 44.77it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.85it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 12.06it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 49.80it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 15.25it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 12.16it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 49.84it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.84it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.93it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 52.18it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.13it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.30it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.04it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.86it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 12.05it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 52.35it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.38it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.20it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 54.12it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 13.97it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 11.96it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 48.72it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.35it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.31it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 49.35it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.77it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.20it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 48.75it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.42it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.99it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 50.57it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.09it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 12.58it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 50.12it/s]
# propagate in video: 100%|██████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.52it/s]
# propagate in video: 100%|██████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.78it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 49.12it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 13.99it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 11.69it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 47.65it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 14.50it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 11.80it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 53.16it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 13.88it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 11.85it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 51.25it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.31it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.07it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 53.72it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 13.78it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 11.68it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 41.00it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.47it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 12.09it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 50.67it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.19it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 12.13it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.45it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.67it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.94it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 50.43it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.14it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.64it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 55.43it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.11it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.77it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 53.08it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.00it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.89it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 51.77it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.41it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.85it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 50.69it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.19it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.12it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 49.64it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.55it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.72it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 51.07it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 14.31it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 11.54it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 52.43it/s]
# propagate in video: 100%|██████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.70it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 11.61it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 51.77it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.68it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.03it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 46.48it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.08it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.27it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 50.06it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.94it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.96it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 48.22it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.06it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.96it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 51.08it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.88it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.83it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 50.97it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.99it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.76it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 47.60it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 13.87it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 11.63it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 50.97it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.71it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 12.01it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 52.17it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.98it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.77it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 51.45it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.56it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.98it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 52.87it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.45it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.97it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 54.09it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 19.79it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 12.26it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 50.81it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 13.64it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 11.57it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 53.23it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 13.82it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 11.62it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 46.61it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 15.38it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 11.75it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 50.39it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 14.25it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 11.60it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 51.85it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.02it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.79it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 47.64it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.15it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.80it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 51.70it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 14.06it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 11.62it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 52.29it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 14.55it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 11.64it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 51.39it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.25it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.87it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 47.47it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.20it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.89it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 50.34it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 14.48it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 11.59it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 50.93it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.16it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.66it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 51.06it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 13.61it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 11.56it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 48.44it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.81it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.80it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 49.37it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 14.26it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 11.57it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 47.74it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.57it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.84it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 47.86it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.16it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.90it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 50.79it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.67it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.91it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 53.24it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.24it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.60it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 52.67it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.26it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.87it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.63it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.27it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.77it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.04it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.25it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.71it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 53.59it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.84it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.76it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 49.93it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.41it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.91it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 52.06it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.05it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.96it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 49.63it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.15it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.81it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 47.82it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.33it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.03it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 51.92it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.96it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.16it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.13it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.02it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.88it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 51.03it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.13it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.83it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 50.78it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.86it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.61it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 47.98it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.71it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.93it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 50.63it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.16it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.07it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 49.70it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.57it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.95it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 49.78it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.72it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.68it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 45.62it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.15it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.75it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 47.32it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.16it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.87it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.57it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.28it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.68it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 48.58it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.99it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.81it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 51.00it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.53it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.74it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 50.50it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 19.48it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 12.58it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 53.31it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.26it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.63it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.48it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.81it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.63it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.08it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 16.16it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.63it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 50.72it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.77it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.60it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 50.58it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.95it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.66it/s]
# frame loading (JPEG): 100%|████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.61it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 15.69it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.77it/s]
# frame loading (JPEG): 100%|██████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 48.41it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 17.78it/s]
# propagate in video: 100%|████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 12.22it/s]
# Results written to temp_patient_VOL_predicted.csv

# %%
# Read the input CSV file
input_csv = 'temp_patient_VOL_predicted.csv'
data = pd.read_csv(input_csv)

# Initialize a list to store the results
ef_results = []

# Group the data by patient ID
grouped = data.groupby('Patient ID')

# Iterate through each patient group
for patient_id, group in grouped:
    # Sort the group by frame name (to ensure EDV and ESV identification)
    group = group.sort_values('Frame Name')
    
    # Ensure there are at least two frames to calculate EF
    if len(group) < 2:
        continue
    
    # Extract EDV (smaller frame number) and ESV (larger frame number)
    edv = group.iloc[0]['EV']  # Volume of the smallest frame
    esv = group.iloc[-1]['EV']  # Volume of the largest frame
    
    # Calculate EF
    ef = (edv - esv) / edv * 100  # Ejection Fraction formula
    
    # Append the patient ID and EF to the results
    ef_results.append([patient_id, ef])

# Write the EF results to a new CSV file
output_csv = 'patient_EF_sam21_finetuned_large.csv'
ef_df = pd.DataFrame(ef_results, columns=['Patient ID', 'EF'])
ef_df.to_csv(output_csv, index=False)

print(f"Ejection Fraction results written to {output_csv}")
# Out:
# Ejection Fraction results written to patient_EF_sam21_finetuned_large.csv
